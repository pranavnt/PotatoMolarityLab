# %% [markdown]
# # Modeling

# %% [markdown]
# ## Data Loading

# %%
# imports
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt 
import seaborn as sns

sns.set()

# %%
df = pd.read_csv('data.csv',header=None)
df
# Out:
#      0    1    2    3    4    5
# 0  1.0  0.8  0.6  0.4  0.2  0.0
# 1  6.0  6.0  7.0  9.0  9.0  9.0
# 2  7.0  6.0  6.0  7.0  9.0  9.0
# 3  5.0  6.0  6.0  7.0  8.0  9.0

# %%
X = np.array(pd.read_csv('data.csv',header=None))[0]
X
# Out:
# array([1. , 0.8, 0.6, 0.4, 0.2, 0. ])

# %%
y = pd.read_csv('data.csv')
y = np.mean(np.array(y),axis=0)
y
# Out:
# array([6.        , 6.        , 6.33333333, 7.66666667, 8.66666667,
#        9.        ])

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Linear Relationship

# %%
plt.scatter(X,y)
plt.title('Molarity vs. Weight (No Transformation)')
plt.xlabel('Molarity (mols)')
plt.ylabel('Weight (g)')
plt.show()
plt.savefig('figures/linear.png')

# %% [markdown]
# ### Exponential Relationship

# %%
plt.scatter(np.log(X),y)
plt.title('Molarity vs. Weight (Log transformation)')
plt.xlabel('Molarity (mols)')
plt.ylabel('Weight (g)')
plt.show()
plt.savefig('figures/exp.png')

# %% [markdown]
# ### Logaritmic Relationship

# %%
plt.scatter(np.exp(X),y)
plt.title('Molarity vs. Weight (exponential transformation)')
plt.xlabel('Molarity (mols)')
plt.ylabel('Weight (g)')
plt.show()
plt.savefig('figures/log.png')

# %% [markdown]
# ## Data Analysis

# %%
from scipy.stats import linregress as LinReg

# %% [markdown]
# ### Linear

# %%
m, b, r, p, std_err = LinReg(X, y)
print("Slope: "+str(m))
print("Intercept: "+str(b))
print("r Value: "+str(r))
print("p Value: "+str(p))
# Out:
# Slope: -3.4761904761904767
# Intercept: 9.015873015873016
# r Value: -0.9586747103918654
# p Value: 0.0025263820993176576

# %% [markdown]
# ### Logarithmic

# %%
m, b, r, p, std_err = LinReg(np.exp(X), y)
print("Slope: "+str(m))
print("Intercept: "+str(b))
print("r Value: "+str(r))
print("p Value: "+str(p))
# Out:
# Slope: -1.9443601786309261
# Intercept: 10.673657600160992
# r Value: -0.9237537622852328
# p Value: 0.008498604825295988

# %% [markdown]
# ### Exponential

# %%
m, b, r, p, std_err = LinReg(np.log(X), y)
print("Slope: "+str(m))
print("Intercept: "+str(b))
print("r Value: "+str(r))
print("p Value: "+str(p))
# Out:
# Slope: nan
# Intercept: nan
# r Value: nan
# p Value: nan
